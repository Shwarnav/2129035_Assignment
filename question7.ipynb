# %%
# Q7.Find the area of the region included between the parabola y2 = x and the line x + y = 2
# and the X-axis.
import numpy as np
import pandas as pd 
import sympy as sym
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %%
x,y=sym.symbols('x y')
e1=sym.Eq(y**2,x)
e2=sym.Eq(x+y,2)
a1=sym.solve((e1,e2),(x,y))
y2=np.linspace(-3,3,100)
x2=y2**2
fig=plt.figure(figsize=(12,7))
plt.plot(x2,y2)
plt.title("GRAPH")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid()
y1=np.linspace(-3,3,100)
x1=2-y1
plt.plot(x1,y1,'red')
area=abs(sym.integrate((2-y)-y**2,(y,1,-2)))
area
# Out:
# 9/2
